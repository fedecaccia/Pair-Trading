# %% [markdown]
# # Data explorer

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data0 = pd.read_csv("data/orderbookGateioXTZBTC.csv", parse_dates=True, index_col="datetime")
data1 = pd.read_csv("data/orderbookHitbtcXTZBTC.csv", parse_dates=True, index_col="datetime")

# %%
data0.head()
# Out:
#                             bid_weight_val_1  bid_weight_count_1  \
# datetime
# 2018-08-27 14:40:38.737894          0.000194         2410.551071
# 2018-08-27 14:43:06.646143          0.000194          528.756835
# 2018-08-27 14:45:23.742876          0.000195          471.585667
# 2018-08-27 14:47:47.828264          0.000195          528.449281
# 2018-08-27 14:50:06.727823          0.000195          528.449265
#
#                             bid_weight_val_2  bid_weight_count_2  bid_val_2  \
# datetime
# 2018-08-27 14:40:38.737894          0.000194         9350.621687   0.000194
# 2018-08-27 14:43:06.646143          0.000194         7808.882150   0.000194
# 2018-08-27 14:45:23.742876          0.000194         4501.877498   0.000194
# 2018-08-27 14:47:47.828264          0.000194         7797.650647   0.000194
# 2018-08-27 14:50:06.727823          0.000194         7848.751234   0.000194
#
#                             bid_count_2  bid_val_1  bid_count_1  bid_val_0  \
# datetime
# ...

# %%
plt.figure(1, figsize=(20,10))
plt.plot(data0["bid_val_0"])
plt.plot(data1["ask_val_1"])
plt.show()

# %%
plt.figure(1, figsize=(20,10))
plt.plot(data0["ask_val_0"])
plt.plot(data1["bid_val_1"], color="red")
plt.show()
